# %% [markdown]
# # Load Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("gdrive/MyDrive/BST281_FinalProject/preprocessing/normalized_data.tsv", sep='\t', index_col=0)
PC_data = pd.read_csv("gdrive/MyDrive/BST281_FinalProject/preprocessing/normalized_data_PC3.tsv", sep='\t', index_col=0)
DU_data = pd.read_csv("gdrive/MyDrive/BST281_FinalProject/preprocessing/normalized_data_DU145.tsv", sep='\t', index_col=0)

# %% [markdown]
# ##PC_count and PC_label (Res:0, Sen:1)

# %%
PC_count = PC_data.iloc[:,4:]
PC_label = PC_data.response.map({'Res':0,'Sen':1})

# %% [markdown]
# ##DU_count and DU_label (Res:0, Sen:1)

# %%
DU_count = DU_data.iloc[:,4:]
DU_label = DU_data.response.map({'Res':0,'Sen':1})

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist

# %% [markdown]
# ##Elbow

# %%
def elbow (data, K):
    distortions = []
    for k in K:
        kmeanModel = KMeans(n_clusters=k).fit(data)
        kmeanModel.fit(data)
        distortions.append(sum(np.min(cdist(data, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / data.shape[0])
    
    # Plot the elbow
    plt.plot(K, distortions, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Distortion')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()

# %%
#K = list(range(10,100,5))
#elbow(data.iloc[:,4:], K)

# %%
K = list(range(10,50,5))
elbow(PC_data.iloc[:,4:], K)

# %%
K = list(range(10,50,5))
elbow(DU_data.iloc[:,4:], K)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2f055647553c> in <module>()
#       1 K = list(range(10,50,5))
# ----> 2 elbow(DU_data.iloc[:,4:], K)
#
# <ipython-input-4-b116ef0b87bd> in elbow(data, K)
#       2     distortions = []
#       3     for k in K:
# ----> 4         kmeanModel = KMeans(n_clusters=k).fit(data)
#       5         kmeanModel.fit(data)
#       6         distortions.append(sum(np.min(cdist(data, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / data.shape[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1141             order="C",
#    1142             copy=self.copy_x,
# -> 1143             accept_large_sparse=False,
#    1144         )
#    1145
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
#kmeanModel = KMeans(n_clusters=2, random_state=0).fit(data)

# %% [markdown]
# 1) elbow, 2) gap statistic, 3) silhouette

# %% [markdown]
# ##Gap Statistic

# %%
# Gap Statistic for K means
def optimalK(data, nrefs, maxClusters):
    """
    Calculates KMeans optimal K using Gap Statistic 
    Params:
        data: ndarry of shape (n_samples, n_features)
        nrefs: number of sample reference datasets to create
        maxClusters: Maximum number of clusters to test for
    Returns: (gaps, optimalK)
    """
    gaps = np.zeros((len(range(1, maxClusters)),))
    resultsdf = pd.DataFrame({'clusterCount':[], 'gap':[]})
    for gap_index, k in enumerate(range(1, maxClusters)):
# Holder for reference dispersion results
        refDisps = np.zeros(nrefs)
# For n references, generate random sample and perform kmeans getting resulting dispersion of each loop
        for i in range(nrefs):
            
            # Create new random reference set
            randomReference = np.random.random_sample(size=data.shape)
            
            # Fit to it
            km = KMeans(k)
            km.fit(randomReference)
            
            refDisp = km.inertia_
            refDisps[i] = refDisp
# Fit cluster to original data and create dispersion
        km = KMeans(k)
        km.fit(data)
        
        origDisp = km.inertia_
# Calculate gap statistic
        gap = np.log(np.mean(refDisps)) - np.log(origDisp)
# Assign this loop's gap statistic to gaps
        gaps[gap_index] = gap
        
        resultsdf = resultsdf.append({'clusterCount':k, 'gap':gap}, ignore_index=True)
    return (gaps.argmax() + 1, resultsdf)

# %%
score_g, df = optimalK(PC_data.iloc[:,4:], nrefs=3, maxClusters=80)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K')

# %%
"""
score_g, df = optimalK(DU_data.iloc[:,4:].astype('float32'), nrefs=3, maxClusters=80)
plt.plot(df['clusterCount'], df['gap'], linestyle='--', marker='o', color='b');
plt.xlabel('K');
plt.ylabel('Gap Statistic');
plt.title('Gap Statistic vs. K')
"""

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
import seaborn as sns

# %% [markdown]
# ##PC

# %%
PC_pca = PCA(n_components=180)
PC_pca.fit(PC_count)
PC_variance = PC_pca.explained_variance_ratio_[0:2,]
PC_count = PC_pca.transform(PC_count)

# %%
sns.scatterplot(PC_count[:,0], PC_count[:,1], hue=PC_label, legend='full')
plt.legend(loc ='lower right')
plt.xlabel('PC1: '+ str(round(PC_variance[0],2)))
plt.ylabel('PC2: '+ str(round(PC_variance[1],2)))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'PC2: 0.08')

# %% [markdown]
# ###Plot PC_loadings

# %%
PC_loadings = PC_pca.components_.T * np.sqrt(PC_pca.explained_variance_)

# %%
plt.scatter(PC_loadings[:,0], PC_loadings[:,1])

# %% [markdown]
# ##DU

# %%
DU_pca = PCA(n_components=DU_count.shape[0])
DU_pca.fit(DU_count)
DU_variance = DU_pca.explained_variance_ratio_[0:2,]
DU_count = DU_pca.transform(DU_count)

# %%
sns.scatterplot(DU_count[:,0], DU_count[:,1], hue=DU_label, legend='full')
plt.legend(loc ='lower right')
plt.xlabel('PC1: '+ str(round(DU_variance[0],2)))
plt.ylabel('PC2: '+ str(round(DU_variance[1],2)))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'PC2: 0.08')

# %% [markdown]
# ###Plot DU_loadings

# %%
DU_loadings = DU_pca.components_.T * np.sqrt(DU_pca.explained_variance_)

# %%
plt.scatter(DU_loadings[:,0], DU_loadings[:,1])

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE

# %% [markdown]
# ##PC

# %%
PC_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(PC_count)

# %%
sns.scatterplot(PC_embedded[:,0], PC_embedded[:,1], hue=PC_label, legend='full')
plt.legend(loc ='lower right')
plt.xlabel('tSNE1')
plt.ylabel('tSNE2')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# ##DU

# %%
DU_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(DU_count)

# %%
sns.scatterplot(DU_embedded[:,0], DU_embedded[:,1], hue=DU_label, legend='full')
plt.legend(loc ='lower right')
plt.xlabel('tSNE1')
plt.ylabel('tSNE2')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'tSNE2')

# %% [markdown]
# #UMAP

# %%
pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 3.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.6.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 34.6 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from umap-learn) (4.64.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=cab1c96b19a604b6a960be6884af93f458be973b9c465415bfa4a09cf2a76d61
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53943 sha256=4a2646ff127f71d8de66aa5d6db565a119cf67203fdff4553f6fc237dc065d90
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.6 umap-learn-0.5.3

# %%
from umap import UMAP

# %% [markdown]
# ##PC

# %%
umap_2d = UMAP(n_components=2, init='random', random_state=0)
PC_proj = umap_2d.fit_transform(PC_count)
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
sns.scatterplot(PC_proj[:,0], PC_proj[:,1], hue=PC_label, legend='full')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##DU

# %%
umap_2d = UMAP(n_components=2, init='random', random_state=0)
DU_proj = umap_2d.fit_transform(DU_count)

# %%
sns.scatterplot(DU_proj[:,0], DU_proj[:,1], hue=DU_label, legend='full')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
